# %%
# import dependencies
import pandas as pd
import glob

# %% [markdown]
# ## Combining Trip Data from Jan 2020 - Jun 2020

# %%
#set path

path = r'C:\Users\getso\OneDrive\Documents\Assignments\Tableau-Challenge\citibike_data\citibike2020'

# make a join string of the CSVs using glob
all_files = glob.glob(path + "/*.csv")

li = []

# read them into a list 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

# concatenate
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
# Concatenate all data into one DataFrame
df_2020 = pd.concat(li, ignore_index=True)

# %%
df_2020
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1                264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2                254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3                429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4                805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
# ...              ...                       ...                       ...
# 137962           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 137963          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 137964          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 137965           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 137966            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#         start station id start station name  start station latitude  \
# ...

# %% [markdown]
# ## Combining Trip Data from Jan 2019 - Dec 2019

# %%
#set path

path = r'C:\Users\getso\OneDrive\Documents\Assignments\Tableau-Challenge\citibike_data\citibike2019'

# make a join string of the CSVs using glob
all_files = glob.glob(path + "/*.csv")

li = []

# read them into a list 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

# concatenate
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
# Concatenate all data into one DataFrame
df_2019 = pd.concat(li, ignore_index=True)

# %%
df_2019
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1                493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2                512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3                196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4                463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
# ...              ...                       ...                       ...
# 404942           621  2019-09-30 23:11:40.0630  2019-09-30 23:22:01.8370
# 404943           167  2019-09-30 23:19:02.9380  2019-09-30 23:21:50.8290
# 404944            94  2019-09-30 23:26:24.7470  2019-09-30 23:27:59.2310
# 404945           366  2019-09-30 23:49:00.4260  2019-09-30 23:55:06.9620
# 404946           150  2019-09-30 23:56:30.1980  2019-09-30 23:59:00.6750
#
#         start station id start station name  start station latitude  \
# ...

# %%
# convert dataframe to csv 
df_2019.to_csv('tripData_2019.csv', sep = ',')

# %%
# convert dataframe to csv 
df_2019.to_csv('tripData_2020.csv', sep = ',')
